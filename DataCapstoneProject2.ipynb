# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %%
df = pd.read_csv('/Users/user/Desktop/Data Science prep/tested.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 31.1+ KB

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Sex'].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
sns.countplot(data=df,x='Pclass')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.distplot(df['Age'],bins=30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-30935ce4d31d> in <module>
# ----> 1 sns.distplot(df['Age'],bins=30,hue='Sex')
#
# TypeError: distplot() got an unexpected keyword argument 'hue'

# %%
df1 = df.drop('Name',axis=1,inplace=False)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            892         0       3    male  34.5      0      0
# 1            893         1       3  female  47.0      1      0
# 2            894         0       2    male  62.0      0      0
# 3            895         0       3    male  27.0      0      0
# 4            896         1       3  female  22.0      1      1
# ..           ...       ...     ...     ...   ...    ...    ...
# 413         1305         0       3    male   NaN      0      0
# 414         1306         1       1  female  39.0      0      0
# 415         1307         0       3    male  38.5      0      0
# 416         1308         0       3    male   NaN      0      0
# 417         1309         0       3    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# ...

# %%
sns.countplot(data=df1,x='Sex',hue='Survived')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
df1
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            892         0       3    male  34.5      0      0
# 1            893         1       3  female  47.0      1      0
# 2            894         0       2    male  62.0      0      0
# 3            895         0       3    male  27.0      0      0
# 4            896         1       3  female  22.0      1      1
# ..           ...       ...     ...     ...   ...    ...    ...
# 413         1305         0       3    male   NaN      0      0
# 414         1306         1       1  female  39.0      0      0
# 415         1307         0       3    male  38.5      0      0
# 416         1308         0       3    male   NaN      0      0
# 417         1309         0       3    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# ...

# %%
df1_adj = df1.copy()
df1_adj['Age'].fillna(df1_adj['Age'].mean(),inplace=True)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            892         0       3    male  34.5      0      0
# 1            893         1       3  female  47.0      1      0
# 2            894         0       2    male  62.0      0      0
# 3            895         0       3    male  27.0      0      0
# 4            896         1       3  female  22.0      1      1
# ..           ...       ...     ...     ...   ...    ...    ...
# 413         1305         0       3    male   NaN      0      0
# 414         1306         1       1  female  39.0      0      0
# 415         1307         0       3    male  38.5      0      0
# 416         1308         0       3    male   NaN      0      0
# 417         1309         0       3    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# ...

# %%
df1_adj
# Out:
#      PassengerId  Survived  Pclass     Sex       Age  SibSp  Parch  \
# 0            892         0       3    male  34.50000      0      0
# 1            893         1       3  female  47.00000      1      0
# 2            894         0       2    male  62.00000      0      0
# 3            895         0       3    male  27.00000      0      0
# 4            896         1       3  female  22.00000      1      1
# ..           ...       ...     ...     ...       ...    ...    ...
# 413         1305         0       3    male  30.27259      0      0
# 414         1306         1       1  female  39.00000      0      0
# 415         1307         0       3    male  38.50000      0      0
# 416         1308         0       3    male  30.27259      0      0
# 417         1309         0       3    male  30.27259      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# ...

# %%
sns.countplot(data=df1_adj,x='Pclass',hue='Survived')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>
